# %%
import numpy as np
import glob
import os
from feature_normalization import process_all_videos_from_directories
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 4
#       2 import glob
#       3 import os
# ----> 4 from feature_normalization import process_all_videos_from_directories
#
# ImportError: cannot import name 'process_all_videos_from_directories' from 'feature_normalization' (/Users/mehdikhosravi/Master/Thesis/STVT-main/STVT/STVT/utils/feature_normalization.py)

# %%
flow_sample=np.load('/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/I3d flow/Air_Force_One.npy')
rgb_sample=np.load('/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/I3d RGB/Air_Force_One.npy')
resnet_sample=np.load('/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/resnet-stvt/Air_Force_One.npy')

# %%
flow_dir="/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/I3d flow/"
rgb_dir="/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/I3d rgb/"
resnet_dir='/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/resnet-stvt/'

# %%
# # For all videos in directories (with PCA):

results = process_all_videos_from_directories(
    rgb_dir,
    flow_dir,
    resnet_dir,
    output_dir='/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/normalized_concat_rfr',
    apply_pca=True,
    pca_dim=512
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 2
#       1 # # For all videos in directories (with PCA):
# ----> 2 from feature_normalization import process_all_videos_from_directories
#       4 results = process_all_videos_from_directories(
#       5     rgb_dir,
#       6     flow_dir,
#    (...)
#      10     pca_dim=512
#      11 )
#
# ImportError: cannot import name 'process_all_videos_from_directories' from 'feature_normalization' (/Users/mehdikhosravi/Master/Thesis/STVT-main/STVT/STVT/utils/feature_normalization.py)

# %%
def stats(name, x):
    print(f"{name}:")
    print("shape:", x.shape)
    print(" mean:", x.mean())
    print(" std :", x.std())
    print(" min :", x.min())
    print(" max :", x.max())
    print("#"*20)

stats("new", np.load('/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/normalized_concat_rfr/Air_Force_One.npy'))
stats("rgb",rgb_sample)
stats("flow",flow_sample)
stats("resnet",resnet_sample)
# Out:
# new:
# shape: (4494, 512)
#  mean: -1.3103299783292902e-16
#  std : 2.2016320885870577
#  min : -35.05050373689324
#  max : 120.23991744679208
# ####################
# rgb:
# shape: (4494, 1024)
#  mean: 0.13469774
#  std : 0.17187561
#  min : 0.0
#  max : 2.1634674
# ####################
# flow:
# shape: (4494, 1024)
#  mean: 0.12139528
#  std : 0.18643355
#  min : 0.0
#  max : 2.7837367
# ####################
# resnet:
# shape: (4494, 512)
#  mean: 20.628675083963472
#  std : 28.60239281029006
#  min : 0.0
#  max : 224.0482635498047
# ####################

# %%
flow_name_files = [f for f in os.listdir(flow_dir) if f.endswith((".npy"))]
print(f"Found {len(flow_features_files)} fature file in {flow_features_files}")
flow_features_files = [f for f in os.listdir(flow_dir) if f.endswith((".npy"))]

# rgb_features_files = [f for f in os.listdir(np.load(rgb_dir)) if f.endswith((".npy"))]
# print(f"Found {len(rgb_features_files)} feature file in {rgb_features_files}")
# stvt_features_files = [f for f in os.listdir(np.load(stvt_dir)) if f.endswith((".npy"))]
# print(f"Found {len(stvt_features_files)} feature file in {stvt_features_files}")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[40], line 5
#       2 rgb_dir="/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/I3d rgb/"
#       3 stvt_dir='/Users/mehdikhosravi/Master/Thesis/STVT-main/Feature extraction/SumMe/Features/resnet-stvt/'
# ----> 5 flow_features_files = [f for f in os.listdir(np.load(flow_dir)) if f.endswith((".npy"))]
#       6 print(f"Found {len(flow_features_files)} fature file in {flow_features_files}")
#       8 rgb_features_files = [f for f in os.listdir(np.load(rgb_dir)) if f.endswith((".npy"))]
#
# File ~/Master/Thesis/STVT-main/venv38/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
# ...

# %%
for i in range(0,25):
    print(np.load(flow_features_files[i]))
